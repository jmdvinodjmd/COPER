# %%
import pandas as pd
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
import sys
import seaborn as sns

# %% [markdown]
# ### Plot Results

# %%
#######################################################################################
# plot the FLOPS for comparison of computational requirements of perceiver and transformer
sheet_name = 'noise-physionet' #physionet, mimic, flops
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

# plot AUPRC
ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data, x="% Irregularity", y="AUPRC", hue='Generation')
plt.legend(loc="lower right", frameon=True, fontsize=16)
# sns.move_legend(ax, "center")
plt.xlabel('% Irregularity', fontsize=16)
# ax.set(xlabel=None)
plt.ylabel('AUPRC', fontsize=16)
ax.set_ylim([.45, .55])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Turns off grid on the left Axis.
ax.grid(False)

# plt.savefig(sheet_name + '.pdf',dpi=300, bbox_inches='tight')

# plot AUROC
ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data, x="% Irregularity", y="AUROC", hue='Generation')
plt.legend(loc="lower right", frameon=True, fontsize=16)
# sns.move_legend(ax, "center")
plt.xlabel('% Irregularity', fontsize=16)
# ax.set(xlabel=None)
plt.ylabel('AUROC', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax.set_ylim([.8, .875])
# Turns off grid on the left Axis.
ax.grid(False)

# plt.savefig(sheet_name + '.pdf',dpi=300, bbox_inches='tight')
#######################################################################################

#######################################################################################
# plot the FLOPS for comparison of computational requirements of perceiver and transformer
sheet_name = 'noise-mimic' #physionet, mimic, flops
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

# plot AUPRC
ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data[data['Model']=='COPER'], x="% Irregularity", y="AUPRC", hue='Generation')
plt.legend(loc="lower right", frameon=True, fontsize=16)
# sns.move_legend(ax, "center")
plt.xlabel('% Irregularity', fontsize=16)
# ax.set(xlabel=None)
plt.ylabel('AUPRC', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Turns off grid on the left Axis.
ax.grid(False)

# plt.savefig(sheet_name + '.pdf',dpi=300, bbox_inches='tight')

# plot AUROC
ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data[data['Model']=='COPER'], x="% Irregularity", y="AUROC", hue='Generation')
plt.legend(loc="lower right", frameon=True, fontsize=16)
# sns.move_legend(ax, "center")
plt.xlabel('% Irregularity', fontsize=16)
# ax.set(xlabel=None)
plt.ylabel('AUROC', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Turns off grid on the left Axis.
ax.grid(False)

# plt.savefig(sheet_name + '.pdf',dpi=300, bbox_inches='tight')
#######################################################################################

# %%
sheet_name = 'mimic' #physionet, mimic
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")

# sns.set(style="darkgrid")

# plot AUROC
p=sns.boxplot(x="% Irregularity", y="AUROC",
            hue="Model", palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
plt.legend(loc="lower left", frameon=True, fontsize=15)
plt.xlabel('% Irregularity', fontsize=15)
plt.ylabel('AUROC', fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.savefig(sheet_name + '-AUROC.pdf', dpi=300,bbox_inches='tight')

# plot AUPRC
fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
sns.set_theme(style="whitegrid", palette="pastel")
p=sns.boxplot(x="% Irregularity", y="AUPRC",
            hue="Model", palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
plt.legend(loc="lower left", frameon=True, fontsize=15)
plt.xlabel('% Irregularity', fontsize=15)
plt.ylabel('AUPRC', fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.savefig(sheet_name + '-AUPRC.pdf',dpi=300, bbox_inches='tight')

#######################################################################################

# %%
sheet_name = 'physionet' #physionet, mimic
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")

# sns.set(style="darkgrid")

# plot AUROC
p=sns.boxplot(x="% Irregularity", y="AUROC",
            hue="Model", palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
plt.legend(loc="lower left", frameon=True, fontsize=14)
plt.xlabel('% Irregularity', fontsize=14)
plt.ylabel('AUROC', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_ylim([.75, .92])
plt.savefig(sheet_name + '-AUROC.pdf', dpi=300,bbox_inches='tight')

# plot AUPRC
fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
sns.set_theme(style="whitegrid", palette="pastel")
p=sns.boxplot(x="% Irregularity", y="AUPRC",
            hue="Model", palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
plt.legend(loc="lower left", frameon=True, fontsize=14)
plt.xlabel('% Irregularity', fontsize=14)
plt.ylabel('AUPRC', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_ylim([.3, .65])
plt.savefig(sheet_name + '-AUPRC.pdf',dpi=300, bbox_inches='tight')

#######################################################################################

# %%
sheet_name = 'physionet-basic' #physionet, mimic
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")

# sns.set(style="darkgrid")

# plot AUROC
p=sns.boxplot(x="Model", y="AUROC",
            palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
# plt.legend(loc="lower left", frameon=True, fontsize=16)
# plt.xlabel('Model', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('AUROC', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig(sheet_name + '-AUROC.pdf', dpi=300,bbox_inches='tight')

# plot AUPRC
fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
sns.set_theme(style="whitegrid", palette="pastel")
p=sns.boxplot(x="Model", y="AUPRC",
            palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
# plt.legend(loc="lower left", frameon=True, fontsize=16)
# plt.xlabel('Model', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('AUPRC', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig(sheet_name + '-AUPRC.pdf',dpi=300, bbox_inches='tight')

#######################################################################################

# %%
sheet_name = 'mimic-basic' #physionet, mimic
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")

# sns.set(style="darkgrid")

# plot AUROC
p=sns.boxplot(x="Model", y="AUROC",
            palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
# plt.legend(loc="lower left", frameon=True, fontsize=16)
# plt.xlabel('Model', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('AUROC', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig(sheet_name + '-AUROC.pdf', dpi=300,bbox_inches='tight')

# plot AUPRC
fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(10,6))
sns.set_theme(style="whitegrid", palette="pastel")
p=sns.boxplot(x="Model", y="AUPRC",
            palette=sns.color_palette(),
            data=data)
sns.despine(offset=10, trim=True)
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
# plt.legend(loc="lower left", frameon=True, fontsize=16)
# plt.xlabel('Model', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('AUPRC', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig(sheet_name + '-AUPRC.pdf',dpi=300, bbox_inches='tight')

#######################################################################################

# %%
#######################################################################################
# plot the FLOPS for comparison of computational requirements of perceiver and transformer
sheet_name = 'flops' #physionet, mimic, flops
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

ig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data, x="Dataset", y="FLOPS", hue='Latents', ci=None)
# plt.legend(loc="upper left", frameon=True, fontsize=16)
sns.move_legend(ax, "center")
# plt.xlabel('Model', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('FLOPS', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Turns off grid on the left Axis.
ax.grid(False)

plt.savefig(sheet_name + '.pdf',dpi=300, bbox_inches='tight')
#######################################################################################
# Out:
# /var/folders/7b/g3bw5x3s3yxdyrkpvzyqyk480000gp/T/ipykernel_39058/1457825793.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x="Dataset", y="FLOPS", hue='Latents', ci=None)

# %%
sheet_name = 'flops-others' #physionet, mimic
data = pd.read_excel('results-final.xlsx', sheet_name=sheet_name)

fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
# sns.set(font_scale = 10)
# sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="whitegrid", palette="pastel")

# sns.set(style="darkgrid")

# plot AUROC
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data, x="Dataset", y="AUROC", hue='Model')
# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
# plt.legend(loc="lower left", frameon=True, fontsize=16)
sns.move_legend(ax, "center")

# plt.xlabel('% Irregularity', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('AUROC', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)
ax.set_ylim([.7, .87])
plt.savefig(sheet_name + '-AUROC.pdf', dpi=300,bbox_inches='tight')

# plot AUPRC
fig, ax = plt.subplots(1, 1,gridspec_kw={'wspace': 0.4},figsize=(8,5))
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(data=data, x="Dataset", y="AUPRC", hue='Model')
# plt.legend(loc="upper left", frameon=True, fontsize=16)

# p.set_ylabel("AUROC", fontsize = 20)
# p.set_xlabel("% Irregularity", fontsize = 20)
# p.set_title("Plot", fontsize = 20)
# plt.legend(labels=["COPER","Perceiver","LSTM"], fontsize = 20)

# plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
#                 mode="expand", borderaxespad=0, ncol=3, frameon=False, fontsize=20)
# plt.legend(loc="lower left", frameon=True, fontsize=16)
sns.move_legend(ax, "center")
# plt.xlabel('% Irregularity', fontsize=16)
ax.set(xlabel=None)
plt.ylabel('AUPRC', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)
ax.set_ylim([.25, .55])
plt.savefig(sheet_name + '-AUPRC.pdf',dpi=300, bbox_inches='tight')

#######################################################################################
